# %% [markdown]
# # Lattice Builder
#
# ### Search for good rank-1 lattices
#
# This Web interface allows Lattice Builder users to call the executable program without having to construct the command line explicitly. Refer to the Lattice Builder Manual and to the reference paper for more information.
#
# Enter the construction parameters below, and press the Search button at the bottom. The results will show at the bottom.
#
# ## Search criteria :

# %%
import warnings
warnings.simplefilter('ignore')

# %%
import sys
sys.path.insert(1, '../share/latnetbuilder')

# %%
import web_ui
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-86a87d843709> in <module>()
# ----> 1 import web_ui
#
# ~/.Trash/latsoft_test 11.16.09/share/latnetbuilder/web_ui/__init__.py in <module>()
#       3 LATBUILDER = './latnet'
#       4
# ----> 5 from .gui import gui
#
# ~/.Trash/latsoft_test 11.16.09/share/latnetbuilder/web_ui/gui/__init__.py in <module>()
#       3 from IPython.display import display
#       4
# ----> 5 from .properties import (modulus, is_multilevel, properties_wrapper,
#       6                          dimension, change_modulus, change_dimension, modulus_pretty)
#       7 from .filters import is_normalization, low_pass_filter, normalization_options, normalization_box, low_pass_filter_options, filters_wrapper, trigger_normalization_warning, normalization_warning, equidistribution_options, equidistribution_level, equidistribution_box, equidistribution_filter, trigger_equidistribution_level
#
# ~/.Trash/latsoft_test 11.16.09/share/latnetbuilder/web_ui/gui/properties.py in <module>()
#       2 import numpy as np
#       3
# ----> 4 from .common import style_default, parse_polynomial, INITIAL_DIM, JoeKuoSobolNets
#       5
#       6 modulus = widgets.Text(placeholder='e.g. 2^10 or 1024', description='Modulus n=',
#
# ~/.Trash/latsoft_test 11.16.09/share/latnetbuilder/web_ui/gui/common.py in <module>()
#      13     _JoeKuoSobolNetsPath = '../share/data/JoeKuoSobolNets.csv'
#      14
# ---> 15 with open(_JoeKuoSobolNetsPath, newline='') as csvfile:
#      16     csvreader = csv.reader(csvfile, delimiter=';')
#      17     i=0
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../data/JoeKuoSobolNets.csv'

# %%
display(web_ui.gui.main_tab)

# %%
import os

# %%
os.path.exists('../share/latnetbuilder/data/JoeKuoSobolNets.csv')
# Out:
# True
